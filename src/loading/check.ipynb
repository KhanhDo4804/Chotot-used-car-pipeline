# %%
import pandas as pd

# %%
f = pd.read_parquet("/home/khanhdo/Documents/project/chotot-pipeline/data/data_cleaning/cleaned_car_details.parquet")
f.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Link          39 non-null     object
#  1   Tên           39 non-null     object
#  2   Giá           39 non-null     int64
#  3   Địa chỉ       39 non-null     object
#  4   Số KM đã đi   39 non-null     int64
#  5   Xuất xứ       39 non-null     object
#  6   Tình trạng    39 non-null     object
#  7   Hãng          39 non-null     object
#  8   Dòng xe       39 non-null     object
#  9   Năm sản xuất  39 non-null     int64
#  10  Hộp số        39 non-null     object
#  11  Nhiên liệu    39 non-null     object
#  12  Kiểu dáng     29 non-null     object
#  13  Số chỗ        34 non-null     object
#  14  crawled_at    39 non-null     object
#  15  listing_id    39 non-null     object
# dtypes: int64(3), object(13)
# memory usage: 5.0+ KB

# %%
f.head(10)
# Out:
#                                                 Link  \
# 0  https://xe.chotot.com/mua-ban-oto/mua-ban-oto-...
# 1  https://xe.chotot.com/mua-ban-oto/mua-ban-oto-...
# 2  https://xe.chotot.com/mua-ban-oto/mua-ban-oto-...
# 3  https://xe.chotot.com/mua-ban-oto/mua-ban-oto-...
# 4  https://xe.chotot.com/mua-ban-oto/mua-ban-oto-...
# 5  https://xe.chotot.com/mua-ban-oto/mua-ban-oto-...
# 6  https://xe.chotot.com/mua-ban-oto/mua-ban-oto-...
# 7  https://xe.chotot.com/mua-ban-oto/mua-ban-oto-...
# 8  https://xe.chotot.com/mua-ban-oto/mua-ban-oto-...
# 9  https://xe.chotot.com/mua-ban-oto/mua-ban-oto-...
#
#                                               Tên        Giá         Địa chỉ  \
# 0     Volkswagen Tiguan Allspace 2018 Đen 98000km  699000000  Tp Hồ Chí Minh
# 1                        Bán góp Vios 20202021 MT  239000000  Tp Hồ Chí Minh
# 2                              MercedesBenz CLA45  550000000      Bình Dương
# ...

# %%
f['listing_id'].value_counts().loc[lambda x: x > 1]
# Out:
# np.int64(6)
